# %%
import pandas as pd

# %%
data = pd.read_csv("ecommerce-data.csv", index_col=False)
data
# Out:
#             Date         ProductName  ProductCategory ProductSubCategory
# 0     2023-09-14           Nathaniel      Electronics             Camera  \
# 1     2023-02-11  NonExistentProduct      Electronics             Mobile
# 2     2021-11-12              Angela  InvalidCategory     Action Figures
# 3     11-15-2021                 Amy    Home & Garden              Decor
# 4     2023-04-22           Nathaniel      Electronics             Camera
# ...          ...                 ...              ...                ...
# 5005  2023-08-24              Angela             Toys     Action Figures
# 5006  2023-08-24              Angela             Toys     Action Figures
# 5007  2023-08-24              Angela             Toys     Action Figures
# 5008  2023-08-24              Angela             Toys     Action Figures
# 5009  2023-08-24              Angela             Toys     Action Figures
#
#      ProductPrice     CustomerName                   CustomerEmail
# ...

# %%
data.duplicated().sum()
# Out:
# 10

# %%
data.dtypes
# Out:
# Date                   object
# ProductName            object
# ProductCategory        object
# ProductSubCategory     object
# ProductPrice           object
# CustomerName           object
# CustomerEmail          object
# CustomerAddress        object
# CustomerPhone          object
# CustomerSegment        object
# SupplierName           object
# SupplierLocation       object
# SupplierContact        object
# ShipperName            object
# ShippingMethod         object
# QuantitySold            int64
# TotalAmount           float64
# DiscountAmount        float64
# NetAmount             float64
# StockReceived           int64
# StockSold               int64
# StockOnHand             int64
# dtype: object

# %%
csv = pd.read_csv("eval.csv")
csv
# Out:
#             Date         ProductName  ProductCategory ProductSubCategory
# 0     2021-10-26             Shannon    Home & Garden    Gardening Tools  \
# 1     2023-07-21             Cynthia  InvalidCategory         Headphones
# 2     2022-05-21               Katie            Books        Non-fiction
# 3     2022-02-05            Kristine      Electronics         Headphones
# 4     2023-09-03                Fred            Books           Academic
# ...          ...                 ...              ...                ...
# 1248  09-08-2023               Shawn  InvalidCategory         Headphones
# 1249  2023-05-10              Martha            Books            Fiction
# 1250  06-05-2023              Angela             Toys     Action Figures
# 1251  2022-03-17              Marvin         Clothing              Shirt
# 1252  2023-04-02  NonExistentProduct      Electronics         Headphones
#
#       ProductPrice       CustomerName                  CustomerEmail
# ...

# %% [markdown]
# # Transformations à réaliser

# %% [markdown]
# - Uniformiser les dates
# - CustomerEmail : valeurs manquantes
# - SupplierContact : valeurs manquantes
# - RGPD : CustomerEmail, CustomerAddress, CustomerPhone, SupplierContact
# - InvalidPrice : TotalAmount/QuantitySold
